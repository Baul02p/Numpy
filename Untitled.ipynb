# %% [markdown]
# <a href="https://colab.research.google.com/github/Baul02p/Numpy/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #alias - np

# %%
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
#Dimension & shape of an array
arr.ndim
# Out:
# 1

# %%
arr = np.array(32)
print(arr)
arr.ndim
# Out:
# 32
# 0

# %%
# 1[] = 1 dimension
# 2[[] []] = 2 dimension and so on

a = np.array([[[[]]]])
a.ndim
a.shape
# Out:
# (1, 1, 1, 0)
